# %% [markdown]
# Регресия - оцените регрессию - построить модель

# %% [markdown]
# datasets - https://github.com/artamonoff/econometrica/tree/main/econometrica-1/datasets

# %%
import pandas as pd
from scipy.stats import f # f-распределение и критические значения
import numpy as np
from statsmodels.formula.api import ols

# импорт данных
df = pd.read_csv('sleep75.csv') #df - название датасета

#print(df['sleep'])
#print(df[['sleep', 'male', 'marr']])

# %%
# оцените регрессию - построить модель
mod1 = ols(formula='sleep ~ male + marr + union + yngkid', data=df)
res1 = mod1.fit() #  название модели
print(res1.summary()) #распечатать полное summary
#res1.params #параметры модели - коэффициенты beta
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sleep   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9476
# Date:                Sun, 24 May 2026   Prob (F-statistic):              0.436
# Time:                        19:15:39   Log-Likelihood:                -5303.7
# No. Observations:                 706   AIC:                         1.062e+04
# Df Residuals:                     701   BIC:                         1.064e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3228.8723     42.632     75.738      0.000    3145.170    3312.575
# male         -40.5350     34.399     -1.178      0.239    -108.072      27.002
# marr          73.7790     44.632      1.653      0.099     -13.850     161.408
# union         12.2628     40.578      0.302      0.763     -67.407      91.933
# yngkid       -22.0123     50.616     -0.435      0.664    -121.390      77.366
# ==============================================================================
# Omnibus:                       64.753   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.903
# Skew:                          -0.461   Prob(JB):                     3.86e-39
# Kurtosis:                       5.272   Cond. No.                         5.18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# оцените значимость - либо смотрим модель в целом либо отдельные коэффициенты (задано в условии задачи)
# модель в целом : F-test (тест Фишера)
# выбранный коэффициент: t-test (тест Фишера)
#
# Робастный /не робастный - по каким формулам считаем.
# робастный - более точный

# %% [markdown]
# проверка модели в целом - F тест
#
# совместная значимость https://github.com/artamonoff/econometrica/blob/main/econometrica-1/jupyter-notebooks/f-test-joint.ipynb

# %%
#F-тест (неробастный)
F_test = res1.f_test('male=marr=union=yngkid=0')
print(F_test) #F - тестовая статистика, p - p-value
# Out:
# <F test: F=0.9475507983315925, p=0.435830025654783, df_denom=701, df_num=4>

# %%
# Тестовая статистика и её P-значение
F_test.statistic, F_test.pvalue
# Out:
# (0.9475507983315925, np.float64(0.435830025654783))

# %%
# уровень значимости - берем из условия
sign_level = 0.01
# Критическое значение F-распределения
f.ppf(q=1-sign_level, dfn=F_test.df_num, dfd=F_test.df_denom)
# Out:
# np.float64(3.345999954245988)

# %% [markdown]
# вывод - если F test > F crit -> модель значима
# если F test  < F crit -> модель не значима

# %%
#F-тест (робастный)
# пересчитываем модель - по-другому считаем ошибки
res2 = mod1.fit(cov_type='HC3')

F_test = res2.f_test('male=marr=union=yngkid=0')
print(F_test)
# Out:
# <F test: F=0.9111208351442787, p=0.45687991095216995, df_denom=701, df_num=4>

# %%
# уровень значимости -    аналогично неробастному тесту
sign_level = 0.01
# Критическое значение F-распределения
f.ppf(q=1-sign_level, dfn=F_test.df_num, dfd=F_test.df_denom)
# Out:
# np.float64(3.345999954245988)

# %%
# неробастный тест.
# модель: sleep ~ age + I(age ** 2) + smsa + yngkid + marг

# %%
import pandas as pd
from scipy.stats import f # f-распределение и критические значения
import numpy as np
from statsmodels.formula.api import ols

# импорт данных
df = pd.read_csv('sleep75.csv') #df - название датасета

# %%
# оцените регрессию - построить модель
mod2 = ols(formula='sleep ~ age + I(age ** 2) + smsa + yngkid + marr', data=df)
res2 = mod2.fit() #  название модели
print(res2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sleep   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     3.167
# Date:                Sun, 24 May 2026   Prob (F-statistic):            0.00778
# Time:                        19:17:11   Log-Likelihood:                -5297.7
# No. Observations:                 706   AIC:                         1.061e+04
# Df Residuals:                     700   BIC:                         1.063e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    3602.5265    235.925     15.270      0.000    3139.322    4065.732
# age           -22.6089     11.892     -1.901      0.058     -45.957       0.739
# I(age ** 2)     0.3145      0.141      2.228      0.026       0.037       0.592
# smsa          -58.2671     34.039     -1.712      0.087    -125.098       8.564
# yngkid         -4.2624     53.239     -0.080      0.936    -108.790     100.265
# marr           62.0964     44.143      1.407      0.160     -24.571     148.764
# ==============================================================================
# Omnibus:                       66.217   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              185.525
# Skew:                          -0.464   Prob(JB):                     5.17e-41
# Kurtosis:                       5.334   Cond. No.                     2.69e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#F-тест (неробастный)
F_test = res2.f_test('age=smsa=yngkid=marr=0')
print(F_test) #F - тестовая статистика, p - p-value
# Out:
# <F test: F=2.1794266004815968, p=0.06972196639854336, df_denom=700, df_num=4>

# %%
# уровень значимости - берем из условия
sign_level = 0.05
# Критическое значение F-распределения
f.ppf(q=1-sign_level, dfn=F_test.df_num, dfd=F_test.df_denom)
# Out:
# np.float64(2.3846561187441107)

# %%
# Совместная значимость коэффициентов - значимость  marr, smsa используя неробастный тест.
# Датасет sleep75
# sleep ~ totwrk + age + south+ male + yngkid + marr

# %%
import pandas as pd
from scipy.stats import f # f-распределение и критические значения
import numpy as np
from statsmodels.formula.api import ols

# импорт данных
df = pd.read_csv('sleep75.csv') #df - название датасета

#print(df['sleep'])
#print(df[['sleep', 'male', 'marr']])

# %%
# оцените регрессию - построить модель
mod1 = ols(formula='sleep ~ totwrk + age + south + male + smsa+ yngkid + marr', data=df)
res1 = mod1.fit() #  название модели
#print(res1.summary()) #распечатать полное summary
res1.params #параметры модели - коэффициенты beta
# Out:
# Intercept    3450.912773
# totwrk         -0.169240
# age             2.689110
# south         101.568463
# male           87.668961
# smsa          -54.747576
# yngkid        -13.962391
# marr           31.210587
# dtype: float64

# %%
#F-тест (неробастный)
F_test = res1.f_test('marr=smsa=0')
print(F_test) #F - тестовая статистика, p - p-value
# Out:
# <F test: F=1.7665374671455731, p=0.17168709999308615, df_denom=698, df_num=2>

# %%
# уровень значимости - берем из условия
sign_level = 0.05
# Критическое значение F-распределения
f.ppf(q=1-sign_level, dfn=F_test.df_num, dfd=F_test.df_denom)
# Out:
# np.float64(3.0086264642691654)
